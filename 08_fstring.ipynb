# %% [markdown]
# # String Formatting and F-Strings

# %%
# String is arguably the most used immutable data types in Python. Python provides multiple ways to format strings, including the
# format() method and f-string (introduced in Python 3.6)

# %% [markdown]
# ### 1. Using format()

# %%
name = "CRISTIANO RONALDO"
age = 41
print("My name is {} and I am {} years old".format(name,age))
# Out:
# My name is CRISTIANO RONALDO and I am 41 years old

# %%
name = input("Enter Your name: ")
age = int(input("Enter your age: "))

print("My name is {} and I am {} years old".format(name,age))
# Out:
# Enter Your name:  Sergio Ramos
# Enter your age:  38
# My name is Sergio Ramos and I am 38 years old

# %%
print("{0} is learning {1}".format("Alice", "Python")) # Using positions
# Out:
# Alice is learning Python

# %%
print("{name} is learning {language}".format(name="Alice", language="Python"))
# Out:
# Alice is learning Python

# %%
print("{0} is {1} time ucl winners". format("Real Madrid",15))
# Out:
# Real Madrid is 15 time ucl winners

# %% [markdown]
# ### 2. Using f-Strings (Recommended)

# %%
# F-strings provide a cleaner and more readable way to format strings.

# %%
name = "Kylian Mbappe"
age = 28

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Kylian Mbappe and I am 28 years old.

# %%
team = "Real Madrid"
print(f"{team} is best in europe")
# Out:
# Real Madrid is best in europe

# %% [markdown]
# #### Expressions Inside f-Strings

# %%
a = 5
b = 10
print(f"Sum of {a} and {b} is {a + b}")
# Out:
# Sum of 5 and 10 is 15

# %% [markdown]
# #### Padding and Alignment

# %%
print(f"{'Python':<10}") # Left-align
print(f"{'Python':>10}") # Right-align
print(f"{'Python':^10}") # Center-align
# Out:
# Python
#     Python
#   Python

# %%
# :<10 → The < symbol means left-align the text within a total width of 10 characters.
# F-strings are the most efficient and recommended way to format strings in modern Python!
