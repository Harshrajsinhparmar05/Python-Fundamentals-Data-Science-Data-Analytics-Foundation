# %% [markdown]
# # Operator Precedence

# %%
# Python follows PEMDAS (Parentheses, Exponents, Multiplication/Division, Addition/Subtraction). The order of operations in Python is:

# %%
# 1. Parentheses () – Highest precedence, operations inside parentheses are evaluated first.
# 2. Exponents ** – Power calculations (e.g., 2 ** 3 → 8)
# 3. Multiplication * , Division / , Floor Division // , Modulus% – Evaluated – Evaluated from left to right.  
# 4. Addition + , Subtraction -  – Evaluated from left to right.

# %%
result = 400*45/55+55-20 ## In this they evalute value from left to right

# %%
result
# Out:
# 362.27272727272725

# %%
400*45                   # 1st step where multiplication action perform because of left ro right rule
# Out:
# 18000

# %%
18000/55+55-20
# Out:
# 362.27272727272725

# %%
18000/55                  # 2nd step after multiplication division will be performed.
# Out:
# 327.27272727272725

# %%
327.27272727272725+55-20   # In the last step python perform first addition and then substraction because of same rule of left to right
# Out:
# 362.27272727272725

# %%
a1 = 11*8/5//7%9          # In this code we perform all MD. Multiplication, division,floor division, module

# %%
a1
# Out:
# 2.0

# %%
11*8                   # In this the same rule is applied left to right  first multiplication
# Out:
# 88

# %%
88/5//7%9
# Out:
# 2.0

# %%
88/5
# Out:
# 17.6

# %%
17.6//7%9
# Out:
# 2.0

# %%
17.6//7
# Out:
# 2.0

# %%
2.0%9
# Out:
# 2.0

# %%
a2 = 999-555+(577-899)      # Here there is different . in this we can see a Parentheses () . 
                            # in Operator precedence Parentheses operations are evaluated first.

# %%
a2
# Out:
# 122

# %%
577-899                    # first they solve parentheses value first
# Out:
# -322

# %%
999-555                   # after that same process restart . evaluate left to right.
# Out:
# 444

# %%
444+ (-322)
# Out:
# 122

# %%
a3 = 2 ** 3 ** 2    # this is a Exponents here  Right-to-left exponentiation

# %%
a3
# Out:
# 512
