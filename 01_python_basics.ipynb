# %% [markdown]
# # Python Basics

# %% [markdown]
# ## Variables, Data Types, and Typecasting

# %% [markdown]
# ### Variables

# %%
 a = 5

# %%
b = 22

# %%
a+b
# Out:
# 27

# %%
name = "Harshraj"

# %%
print(name) # print function
# Out:
# Harshraj

# %%
# this is single line comment

# %% [markdown]
# ### Data types

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(a)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
b = 10 -2                 # this is integer a whole number
c = "Coders"              # this is string 
d = 3.14                  # this is float number. It write in (.) decimal numbers
e = True                  # this is boolean value. It is only write TRUE and False
f = ["Python","Jupyter","Conda"] # this is a list. written in [] square bracket
g = (1,2,3)               # this is a tuple. written in () round bracket.
h = {"a": 1}              # this is a dictionary. written in {} curly bracket with key and value pair. "a" key : 1 value

# %%
type(b)
# Out:
# int

# %%
type (c)
# Out:
# str

# %%
type (d)
# Out:
# float

# %%
type (e)
# Out:
# bool

# %%
type (f)
# Out:
# list

# %%
type (g)
# Out:
# tuple

# %%
type (h)
# Out:
# dict

# %% [markdown]
# ### Typecasting (Type Conversion)

# %% [markdown]
# ##### str to int

# %%
c = "5677" # 5677 & 4821 is now string

# %%
d = "4821"

# %%
c + d         # when we use + this the two string is join to each other
# Out:
# '56774821'

# %%
int(c) + int(d) # now we Convert data from one type to another using built-in functions:
# Out:
# 10498

# %% [markdown]
# ##### int to str

# %%
a1 = 55

# %%
b1 = 24

# %%
a1 + b1
# Out:
# 79

# %%
str(a1) + str(b1)
# Out:
# '5524'

# %% [markdown]
# ##### float to int

# %%
a2 = 15.6

# %%
a2
# Out:
# 15.6

# %%
int(a2)
# Out:
# 15

# %% [markdown]
# ##### list from string

# %%
b2 = "Python"

# %%
b2
# Out:
# 'Python'

# %%
list(b2)
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %% [markdown]
# ####  Use type(variable) to check a variable’s data type. Typecasting errors can happen if the value isn’t compatible
